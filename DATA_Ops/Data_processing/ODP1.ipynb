# %%
import pandas as pd
import numpy as np

# %%
od= pd.read_csv("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Raw_Data/official_data.csv")
od.head(5)
# Out:
#            Date Range  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0           From Date  31/07/2024        NaN        NaN        NaN        NaN
# 1             To Date  20/01/2025        NaN        NaN        NaN        NaN
# 2                 NaN         NaN        NaN        NaN        NaN        NaN
# 3  Equity P&L Summary         NaN        NaN        NaN        NaN        NaN
# 4     Total Gross PnL    -1353.77        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN        NaN        NaN        NaN         NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN         NaN
#
# ...

# %%
od.iloc[25]
od.shape
# Out:
# (67, 20)

# %%
od.iloc[25]
# Out:
# Date Range             Scrip Symbol
# Unnamed: 1             Company Name
# Unnamed: 2                 Quantity
# Unnamed: 3            Avg Buy Price
# Unnamed: 4                Buy Value
# Unnamed: 5           Avg Sell Price
# Unnamed: 6               Sell Value
# Unnamed: 7                Gross PnL
# Unnamed: 8                Brokerage
# Unnamed: 9                      GST
# Unnamed: 10    Exchange Service Tax
# Unnamed: 11            Turnover Tax
# Unnamed: 12            SEBI Charges
# Unnamed: 13              Stamp Duty
# Unnamed: 14                     STT
# Unnamed: 15           Other Charges
# Unnamed: 16            IPFT Charges
# Unnamed: 17            Intraday PnL
# Unnamed: 18                     NaN
# Unnamed: 19                     NaN
# Name: 25, dtype: object

# %%
od1 = od.iloc[25:67]
od1.head(5)
# Out:
#       Date Range                Unnamed: 1 Unnamed: 2     Unnamed: 3  \
# 25  Scrip Symbol              Company Name   Quantity  Avg Buy Price
# 26            LT      LARSEN & TOUBRO LTD.         20        3590.63
# 27      RELIANCE   RELIANCE INDUSTRIES LTD         20        1243.65
# 28           TCS  TATA CONSULTANCY SERV LT          6         4301.5
# 29         IREDA   INDIAN RENEWABLE ENERGY         60          215.4
#
#    Unnamed: 4      Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 25  Buy Value  Avg Sell Price  Sell Value  Gross PnL  Brokerage        GST
# 26    71812.5         3587.98     71759.5        -53      43.07       8.57
# 27      24873          1239.1       24782        -91       14.9       2.96
# 28      25809         4273.55     25641.3     -167.7      15.44       3.07
# 29      12924          212.11    12726.53    -197.47        7.7       1.53
#
#              Unnamed: 10   Unnamed: 11   Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# ...

# %%
od1.columns = od1.iloc[0]
od1 = od1.drop(od1.index[0])
od1.head(5)
# Out:
# 25 Scrip Symbol              Company Name Quantity Avg Buy Price Buy Value  \
# 26           LT      LARSEN & TOUBRO LTD.       20       3590.63   71812.5
# 27     RELIANCE   RELIANCE INDUSTRIES LTD       20       1243.65     24873
# 28          TCS  TATA CONSULTANCY SERV LT        6        4301.5     25809
# 29        IREDA   INDIAN RENEWABLE ENERGY       60         215.4     12924
# 30          M&M   MAHINDRA & MAHINDRA LTD        9       3133.96  28205.65
#
# 25 Avg Sell Price Sell Value Gross PnL Brokerage   GST Exchange Service Tax  \
# 26        3587.98    71759.5       -53     43.07  8.57                    0
# 27         1239.1      24782       -91      14.9  2.96                    0
# 28        4273.55    25641.3    -167.7     15.44  3.07                    0
# 29         212.11   12726.53   -197.47       7.7  1.53                    0
# 30         3122.1    28098.9   -106.75     16.89  3.36                    0
#
# ...

# %%
od1.columns
# Out:
# Index([        'Scrip Symbol',         'Company Name',             'Quantity',
#               'Avg Buy Price',            'Buy Value',       'Avg Sell Price',
#                  'Sell Value',            'Gross PnL',            'Brokerage',
#                         'GST', 'Exchange Service Tax',         'Turnover Tax',
#                'SEBI Charges',           'Stamp Duty',                  'STT',
#               'Other Charges',         'IPFT Charges',         'Intraday PnL',
#                           nan,                    nan],
#       dtype='object', name=25)

# %%
columns_added = ['GST', 'Exchange Service Tax',         'Turnover Tax',
               'SEBI Charges',           'Stamp Duty',                  'STT',
              'Other Charges',         'IPFT Charges']

# %%
od1['Add Charges'] = od1[columns_added].sum(axis=1)
od1 = od1.drop(columns=columns_added)
od1 = od1.drop(columns=[col for col in od1.columns if pd.isna(col)])

od1.head(5)
# Out:
# 25 Scrip Symbol              Company Name Quantity Avg Buy Price Buy Value  \
# 26           LT      LARSEN & TOUBRO LTD.       20       3590.63   71812.5
# 27     RELIANCE   RELIANCE INDUSTRIES LTD       20       1243.65     24873
# 28          TCS  TATA CONSULTANCY SERV LT        6        4301.5     25809
# 29        IREDA   INDIAN RENEWABLE ENERGY       60         215.4     12924
# 30          M&M   MAHINDRA & MAHINDRA LTD        9       3133.96  28205.65
#
# 25 Avg Sell Price Sell Value Gross PnL Brokerage Intraday PnL  \
# 26        3587.98    71759.5       -53     43.07      -129.19
# 27         1239.1      24782       -91      14.9      -117.44
# 28        4273.55    25641.3    -167.7     15.44      -194.84
# 29         212.11   12726.53   -197.47       7.7      -210.51
# 30         3122.1    28098.9   -106.75     16.89      -136.79
#
# 25            Add Charges
# 26  8.5704.260.1421800.14
# 27   2.9601.470.051600.05
# 28   3.0701.530.051600.05
# 29   1.5300.760.030300.03
# ...

# %%
od1 = od1.drop(columns=[col for col in od1.columns if pd.isna(col)])
od1.head()
# Out:
# 25 Scrip Symbol              Company Name Quantity Avg Buy Price Buy Value  \
# 0            LT      LARSEN & TOUBRO LTD.       20       3590.63   71812.5
# 1      RELIANCE   RELIANCE INDUSTRIES LTD       20       1243.65     24873
# 2           TCS  TATA CONSULTANCY SERV LT        6        4301.5     25809
# 3         IREDA   INDIAN RENEWABLE ENERGY       60         215.4     12924
# 4           M&M   MAHINDRA & MAHINDRA LTD        9       3133.96  28205.65
#
# 25 Avg Sell Price Sell Value Gross PnL Brokerage Intraday PnL  \
# 0         3587.98    71759.5       -53     43.07      -129.19
# 1          1239.1      24782       -91      14.9      -117.44
# 2         4273.55    25641.3    -167.7     15.44      -194.84
# 3          212.11   12726.53   -197.47       7.7      -210.51
# 4          3122.1    28098.9   -106.75     16.89      -136.79
#
# 25            Add Charges
# 0   8.5704.260.1421800.14
# 1    2.9601.470.051600.05
# 2    3.0701.530.051600.05
# 3    1.5300.760.030300.03
# ...

# %%
col_order= od1.columns.tolist()
col_order.insert(col_order.index("Brokerage")+1,col_order.pop(col_order.index("Add Charges")))
od1=od1[col_order]
od1.head()
# Out:
# 25 Scrip Symbol              Company Name Quantity Avg Buy Price Buy Value  \
# 0            LT      LARSEN & TOUBRO LTD.       20       3590.63   71812.5
# 1      RELIANCE   RELIANCE INDUSTRIES LTD       20       1243.65     24873
# 2           TCS  TATA CONSULTANCY SERV LT        6        4301.5     25809
# 3         IREDA   INDIAN RENEWABLE ENERGY       60         215.4     12924
# 4           M&M   MAHINDRA & MAHINDRA LTD        9       3133.96  28205.65
#
# 25 Avg Sell Price Sell Value Gross PnL Brokerage            Add Charges  \
# 0         3587.98    71759.5       -53     43.07  8.5704.260.1421800.14
# 1          1239.1      24782       -91      14.9   2.9601.470.051600.05
# 2         4273.55    25641.3    -167.7     15.44   3.0701.530.051600.05
# 3          212.11   12726.53   -197.47       7.7   1.5300.760.030300.03
# 4          3122.1    28098.9   -106.75     16.89   3.3601.670.061700.06
#
# 25 Intraday PnL
# 0       -129.19
# 1       -117.44
# 2       -194.84
# ...

# %%
od1["Opted"]=np.where(od1["Avg Buy Price"]<od1["Avg Sell Price"],"BUYYY","SELL")
od1.tail(5)
# Out:
# 25 Scrip Symbol         Company Name Quantity Avg Buy Price  Buy Value  \
# 62   TATAMOTORS  TATA MOTORS LIMITED       17          1079      18343
# 63   TATAMOTORS  TATA MOTORS LIMITED       19       1049.25   19935.75
# 64   TATAMOTORS  TATA MOTORS LIMITED       20       1026.75      20535
# 65   TATAMOTORS  TATA MOTORS LIMITED       18        1045.8    18824.4
# 66        Total                  NaN      NaN           NaN  1224006.1
#
# 25 Avg Sell Price  Sell Value Gross PnL Brokerage Intraday PnL  \
# 62         1073.8     18254.6     -88.4     10.98      -108.79
# 63        1040.35    19766.65    -169.1     11.91      -190.71
# 64        1020.46     20409.1    -125.9     12.28         -148
# 65        1057.55     19035.9     211.5     11.36       190.61
# 66            NaN  1222652.33  -1353.77    733.99     -2657.35
#
# 25                    Add Charges  Opted
# 62              2.1901.180.041500   SELL
# 63              2.3801.280.041500   SELL
# ...

# %%
od1 = od1[::-1].reset_index(drop=True)

od1.head(5)
# Out:
# 25 Scrip Symbol         Company Name Quantity Avg Buy Price  Buy Value  \
# 0         Total                  NaN      NaN           NaN  1224006.1
# 1    TATAMOTORS  TATA MOTORS LIMITED       18        1045.8    18824.4
# 2    TATAMOTORS  TATA MOTORS LIMITED       20       1026.75      20535
# 3    TATAMOTORS  TATA MOTORS LIMITED       19       1049.25   19935.75
# 4    TATAMOTORS  TATA MOTORS LIMITED       17          1079      18343
#
# 25 Avg Sell Price  Sell Value Gross PnL Brokerage Intraday PnL  \
# 0             NaN  1222652.33  -1353.77    733.99     -2657.35
# 1         1057.55     19035.9     211.5     11.36       190.61
# 2         1020.46     20409.1    -125.9     12.28         -148
# 3         1040.35    19766.65    -169.1     11.91      -190.71
# 4          1073.8     18254.6     -88.4     10.98      -108.79
#
# 25                    Add Charges  Opted
# 0   146.35075.062.4741302.9901.72   SELL
# 1               2.2701.220.041500  BUYYY
# ...

# %%
od1=od1.iloc[1:]
od1.head(5)
# Out:
# 25 Scrip Symbol         Company Name Quantity Avg Buy Price Buy Value  \
# 1    TATAMOTORS  TATA MOTORS LIMITED       18        1045.8   18824.4
# 2    TATAMOTORS  TATA MOTORS LIMITED       20       1026.75     20535
# 3    TATAMOTORS  TATA MOTORS LIMITED       19       1049.25  19935.75
# 4    TATAMOTORS  TATA MOTORS LIMITED       17          1079     18343
# 5    TATAMOTORS  TATA MOTORS LIMITED       34       1059.88  36035.75
#
# 25 Avg Sell Price Sell Value Gross PnL Brokerage Intraday PnL  \
# 1         1057.55    19035.9     211.5     11.36       190.61
# 2         1020.46    20409.1    -125.9     12.28         -148
# 3         1040.35   19766.65    -169.1     11.91      -190.71
# 4          1073.8    18254.6     -88.4     10.98      -108.79
# 5         1063.29      36152    116.25     21.66        77.86
#
# 25        Add Charges  Opted
# 1   2.2701.220.041500  BUYYY
# 2   2.4601.320.041500   SELL
# 3   2.3801.280.041500   SELL
# 4   2.1901.180.041500   SELL
# ...

# %%
od1 = pd.concat([od1.iloc[1:], od1.iloc[[0]]]).reset_index(drop=True)

# %%
od1.head(5)
# Out:
# 25 Scrip Symbol         Company Name Quantity Avg Buy Price Buy Value  \
# 1    TATAMOTORS  TATA MOTORS LIMITED       18        1045.8   18824.4
# 2    TATAMOTORS  TATA MOTORS LIMITED       20       1026.75     20535
# 3    TATAMOTORS  TATA MOTORS LIMITED       19       1049.25  19935.75
# 4    TATAMOTORS  TATA MOTORS LIMITED       17          1079     18343
# 5    TATAMOTORS  TATA MOTORS LIMITED       34       1059.88  36035.75
#
# 25 Avg Sell Price Sell Value Gross PnL Brokerage Intraday PnL  \
# 1         1057.55    19035.9     211.5     11.36       190.61
# 2         1020.46    20409.1    -125.9     12.28         -148
# 3         1040.35   19766.65    -169.1     11.91      -190.71
# 4          1073.8    18254.6     -88.4     10.98      -108.79
# 5         1063.29      36152    116.25     21.66        77.86
#
# 25        Add Charges  Opted
# 1   2.2701.220.041500  BUYYY
# 2   2.4601.320.041500   SELL
# 3   2.3801.280.041500   SELL
# 4   2.1901.180.041500   SELL
# ...

# %%
uod=pd.read_csv("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Raw_Data/Unofficial_data1.csv")
uod.head()
# Out:
#    Pre Funds        DATE        STOCK    OPTED             VOLUME  RSI   RR  \
# 0     4000.00   August 5  TATA Motors      BUY      1.4M u - 450k   30    2
# 1     4190.00   August 7  TATA Motors  No Data  NO DATA AVAILABLE  NaN  NaN
# 2     4042.00   August 8  TATA Motors      NaN                NaN  NaN  NaN
# 3     3851.00  August 12  TATA Motors      NaN                NaN  NaN  NaN
# 4     3742.21  August 13  TATA Motors      NaN                NaN  NaN  NaN
#
#    TAR RR  PR0 / LOSS  Brokerage     NET  Post Funds
# 0     2.0      210.00        NaN  190.69      4190.00
# 1     NaN      126.00        NaN -148.00      4042.00
# 2     NaN      169.00        NaN -190.71      3851.00
# 3     NaN       88.00        NaN -108.79      3742.21
# 4     NaN      115.94        NaN   77.44      3819.65

# %%
od1.head(5)
# Out:
# 25 Scrip Symbol         Company Name Quantity Avg Buy Price Buy Value  \
# 1    TATAMOTORS  TATA MOTORS LIMITED       18        1045.8   18824.4
# 2    TATAMOTORS  TATA MOTORS LIMITED       20       1026.75     20535
# 3    TATAMOTORS  TATA MOTORS LIMITED       19       1049.25  19935.75
# 4    TATAMOTORS  TATA MOTORS LIMITED       17          1079     18343
# 5    TATAMOTORS  TATA MOTORS LIMITED       34       1059.88  36035.75
#
# 25 Avg Sell Price Sell Value Gross PnL Brokerage Intraday PnL  \
# 1         1057.55    19035.9     211.5     11.36       190.61
# 2         1020.46    20409.1    -125.9     12.28         -148
# 3         1040.35   19766.65    -169.1     11.91      -190.71
# 4          1073.8    18254.6     -88.4     10.98      -108.79
# 5         1063.29      36152    116.25     21.66        77.86
#
# 25        Add Charges  Opted
# 1   2.2701.220.041500  BUYYY
# 2   2.4601.320.041500   SELL
# 3   2.3801.280.041500   SELL
# 4   2.1901.180.041500   SELL
# ...

# %%
mod1=od1.to_csv('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Cleaned_Data/MOD2.csv')

# %%
mod2=pd.read_csv('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Cleaned_Data/MOD2.csv')
mod2.head()
# Out:
#    Unnamed: 0 Scrip Symbol         Company Name  Quantity  Avg Buy Price  \
# 0           1   TATAMOTORS  TATA MOTORS LIMITED        18        1045.80
# 1           2   TATAMOTORS  TATA MOTORS LIMITED        20        1026.75
# 2           3   TATAMOTORS  TATA MOTORS LIMITED        19        1049.25
# 3           4   TATAMOTORS  TATA MOTORS LIMITED        17        1079.00
# 4           5   TATAMOTORS  TATA MOTORS LIMITED        34        1059.88
#
#    Buy Value  Avg Sell Price  Sell Value  Gross PnL  Brokerage  Intraday PnL  \
# 0   18824.40         1057.55    19035.90     211.50      11.36        190.61
# 1   20535.00         1020.46    20409.10    -125.90      12.28       -148.00
# 2   19935.75         1040.35    19766.65    -169.10      11.91       -190.71
# 3   18343.00         1073.80    18254.60     -88.40      10.98       -108.79
# 4   36035.75         1063.29    36152.00     116.25      21.66         77.86
#
#          Add Charges  Opted
# 0  2.2701.220.041500  BUYYY
# ...

# %%
comparsion=pd.DataFrame({'od1':mod2['Scrip Symbol'],'od2':uod['STOCK']})
print(comparsion)
# Out:
#            od1              od2
# 0   TATAMOTORS      TATA Motors
# 1   TATAMOTORS      TATA Motors
# 2   TATAMOTORS      TATA Motors
# 3   TATAMOTORS      TATA Motors
# 4   TATAMOTORS      TATA Motors
# 5   TATAMOTORS      TATA Motors
# 6   TATAMOTORS      TATA Motors
# 7   TATAMOTORS      TATA Motors
# 8   TATAMOTORS      TATA Motors
# 9   TATAMOTORS      TATA Motors
# 10  TATAMOTORS      TATA Motors
# 11        OFSS             OFSS
# 12        OFSS             OFSS
# 13     OLAELEC          OLAELEC
# 14         TCS              TCS
# 15    ADANIENT        Adani Ent
# 16          LT               LT
# 17      APOLLO        Apollo MS
# 18   SOUTHBANK  South INdian Bk
# 19     MAZDOCK          MAZDOCK
# 20        INFY             Infy
# 21          LT               LT
# 22    HDFCLIFE        Hdfc Life
# 23  TATAMOTORS      Tata Motors
# 24    RELIANCE         Reliance
# 25       TECHM           Tech M
# 26       WIPRO            Wipro
# 27   TATASTEEL      tata steel
# ...

# %%
od1.to_csv("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Raw_Data/MOD1.csv",index=False)

# %%
od2=pd.read_csv("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Cleaned_Data/MOD1.csv")
od2.head()
# Out:
#   Scrip Symbol         Company Name  Quantity  Avg Buy Price  Buy Value  \
# 0   TATAMOTORS  TATA MOTORS LIMITED      18.0        1045.80   18824.40
# 1   TATAMOTORS  TATA MOTORS LIMITED      20.0        1026.75   20535.00
# 2   TATAMOTORS  TATA MOTORS LIMITED      19.0        1049.25   19935.75
# 3   TATAMOTORS  TATA MOTORS LIMITED      17.0        1079.00   18343.00
# 4   TATAMOTORS  TATA MOTORS LIMITED      34.0        1059.88   36035.75
#
#    Avg Sell Price  Sell Value  Gross PnL  Brokerage        Add Charges  \
# 0         1057.55    19035.90     211.50      11.36  2.2701.220.041500
# 1         1020.46    20409.10    -125.90      12.28  2.4601.320.041500
# 2         1040.35    19766.65    -169.10      11.91  2.3801.280.041500
# 3         1073.80    18254.60     -88.40      10.98  2.1901.180.041500
# 4         1063.29    36152.00     116.25      21.66  4.3302.320.071900
#
#    Intraday PnL  Opted
# 0        190.61  BUYYY
# 1       -148.00   SELL
# 2       -190.71   SELL
# ...

# %%
col_to_move=['Pre Funds ','DATE','VOLUME','RSI','RR','TAR RR','Post Funds ']
od2=pd.concat([od2,uod[col_to_move]],axis=1)
od2.head(5)
# Out:
#   Scrip Symbol         Company Name  Quantity  Avg Buy Price  Buy Value  \
# 0   TATAMOTORS  TATA MOTORS LIMITED      18.0        1045.80   18824.40
# 1   TATAMOTORS  TATA MOTORS LIMITED      20.0        1026.75   20535.00
# 2   TATAMOTORS  TATA MOTORS LIMITED      19.0        1049.25   19935.75
# 3   TATAMOTORS  TATA MOTORS LIMITED      17.0        1079.00   18343.00
# 4   TATAMOTORS  TATA MOTORS LIMITED      34.0        1059.88   36035.75
#
#    Avg Sell Price  Sell Value  Gross PnL  Brokerage        Add Charges  \
# 0         1057.55    19035.90     211.50      11.36  2.2701.220.041500
# 1         1020.46    20409.10    -125.90      12.28  2.4601.320.041500
# 2         1040.35    19766.65    -169.10      11.91  2.3801.280.041500
# 3         1073.80    18254.60     -88.40      10.98  2.1901.180.041500
# 4         1063.29    36152.00     116.25      21.66  4.3302.320.071900
#
#    Intraday PnL  Opted  Pre Funds        DATE             VOLUME  RSI   RR  \
# ...

# %%
cols = list(od2.columns)

# %%
od1 = od1[::-1].reset_index(drop=True)
od1.head(5)
# Out:
#   Scrip Symbol          Company Name Quantity Avg Buy Price  Buy Value  \
# 0           LT  LARSEN & TOUBRO LTD.       20       3590.63    71812.5
# 1        Total                   NaN      NaN           NaN  1224006.1
# 2   TATAMOTORS   TATA MOTORS LIMITED       18        1045.8    18824.4
# 3   TATAMOTORS   TATA MOTORS LIMITED       20       1026.75      20535
# 4   TATAMOTORS   TATA MOTORS LIMITED       19       1049.25   19935.75
#
#   Avg Sell Price  Sell Value Gross PnL Brokerage  \
# 0        3587.98     71759.5       -53     43.07
# 1            NaN  1222652.33  -1353.77    733.99
# 2        1057.55     19035.9     211.5     11.36
# 3        1020.46     20409.1    -125.9     12.28
# 4        1040.35    19766.65    -169.1     11.91
#
#                      Add Charges Intraday PnL  Opted  Pre Funds     DATE  \
# 0          8.5704.260.1421800.14      -129.19   SELL         NaN     NaN
# 1  146.35075.062.4741302.9901.72     -2657.35   SELL     7427.48  20 Jan
# ...

# %%
od1.to_csv("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Cleaned_Data/MOD2.csv")

# %% [markdown]
# ### Second part of DATA MODIFICATION

# %% [markdown]
# Plan is to,
# 1. Fill in empty values
# 2. Add extra Data (
#     US Bond yields,
#     Indian Market Changes,
#     FII/DII Data,
#     Gold Rates,
#     Extra Variable Data eg. Gift
# )

# %%
uod.head(5)
# Out:
#    Pre Funds        DATE        STOCK    OPTED             VOLUME  RSI   RR  \
# 0     4000.00   August 5  TATA Motors      BUY      1.4M u - 450k   30    2
# 1     4190.00   August 7  TATA Motors  No Data  NO DATA AVAILABLE  NaN  NaN
# 2     4042.00   August 8  TATA Motors      NaN                NaN  NaN  NaN
# 3     3851.00  August 12  TATA Motors      NaN                NaN  NaN  NaN
# 4     3742.21  August 13  TATA Motors      NaN                NaN  NaN  NaN
#
#    TAR RR  PR0 / LOSS  Brokerage     NET  Post Funds
# 0     2.0      210.00        NaN  190.69      4190.00
# 1     NaN      126.00        NaN -148.00      4042.00
# 2     NaN      169.00        NaN -190.71      3851.00
# 3     NaN       88.00        NaN -108.79      3742.21
# 4     NaN      115.94        NaN   77.44      3819.65

# %%
col_add = [
    'Pre Funds ',
    'Post Funds ',
    'DATE',
    'RSI',
    'VOLUME',
    'RR',
    'TAR RR'
]
pd.concat([od2,uod[col_add]],axis=1)
# Out:
#    Scrip Symbol               Company Name  Quantity  Avg Buy Price  \
# 0    TATAMOTORS        TATA MOTORS LIMITED      18.0        1045.80
# 1    TATAMOTORS        TATA MOTORS LIMITED      20.0        1026.75
# 2    TATAMOTORS        TATA MOTORS LIMITED      19.0        1049.25
# 3    TATAMOTORS        TATA MOTORS LIMITED      17.0        1079.00
# 4    TATAMOTORS        TATA MOTORS LIMITED      34.0        1059.88
# 5    TATAMOTORS        TATA MOTORS LIMITED      17.0        1050.00
# 6    TATAMOTORS        TATA MOTORS LIMITED      17.0        1098.50
# 7    TATAMOTORS        TATA MOTORS LIMITED      16.0        1091.55
# 8    TATAMOTORS        TATA MOTORS LIMITED      16.0        1086.65
# 9    TATAMOTORS        TATA MOTORS LIMITED      16.0        1086.05
# 10   TATAMOTORS        TATA MOTORS LIMITED      16.0        1082.45
# 11         OFSS  ORACLE FIN SERV SOFT LTD.       6.0       11352.74
# 12         OFSS  ORACLE FIN SERV SOFT LTD.       3.0       11714.00
# ...

# %%
MOD2=od2.to_csv("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Cleaned_Data/MOD3.csv")

# %%
od2=pd.read_csv("/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Cleaned_Data/MOD3.csv")
