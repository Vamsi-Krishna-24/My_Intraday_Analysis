# %%
bata = [1,2,3,4]

# %%
from  prettytable import PrettyTable
import pandas as pd

# %%
attributes = ['name','age','team']

data = [
    ['V.Kohli','30','RCB'],
    ['chahal','28','RCB'],
    ['Sharukh','25','KKR'],
    ['chrisgayle','40','RCB'],
    ['ABd','35','RCB']
]

data = pd.DataFrame(data, columns=attributes)
data
# Out:
#          name age team
# 0     V.Kohli  30  RCB
# 1      chahal  28  RCB
# 2     Sharukh  25  KKR
# 3  chrisgayle  40  RCB
# 4         ABd  35  RCB

# %%
table={

'movie':['Arjun Reddy','Goat','Kalki'],
'rating':[8,9,7],
'hero':['Vijay','R','Prabhas']

}

for key in table:
    print(f"{key}:{table[key]}")
# Out:
# movie:['Arjun Reddy', 'Goat', 'Kalki']
# rating:[8, 9, 7]
# hero:['Vijay', 'R', 'Prabhas']

# %%
table = PrettyTable(['movie','rating','hero'])
table.add_row(['Arjun Reddy',8,'Vijay'])
table.add_row(['Goat',9,'R'])
table.add_row(['Kalki',7,'Prabhas'])
table.add_row(['KGF',8,'Yash'])
print(table)
# Out:
# +-------------+--------+---------+
# |    movie    | rating |   hero  |
# +-------------+--------+---------+
# | Arjun Reddy |   8    |  Vijay  |
# |     Goat    |   9    |    R    |
# |    Kalki    |   7    | Prabhas |
# |     KGF     |   8    |   Yash  |
# +-------------+--------+---------+

# %%
data= pd.read_csv('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Cleaned_Data/Monthly_Trades.csv')
data.head()
# Out:
#            MONTH   NO OF TRADES REALIZED PL   CHARGES NET REALIZED\nPL
# 0    January-2025             8   -₹ 126.37  ₹ 239.70        -₹ 366.07
# 1   November-2024             5   -₹ 947.90  ₹ 119.17      -₹ 1,067.07
# 2    October-2024            14    ₹ 341.05  ₹ 596.97        -₹ 255.92
# 3  September-2024             2   -₹ 469.45  ₹ 110.01        -₹ 579.46
# 4     August-2024            11   -₹ 151.10  ₹ 237.74        -₹ 388.84

# %% [markdown]
# #### Cleaning unwanted cells

# %%
fata=pd.read_csv('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Cleaned_Data/Monthly_Trades.csv')
fata.head()
# Out:
#            MONTH   NO OF TRADES REALIZED PL   CHARGES NET REALIZED\nPL
# 0    January-2025             8   -₹ 126.37  ₹ 239.70        -₹ 366.07
# 1   November-2024             5   -₹ 947.90  ₹ 119.17      -₹ 1,067.07
# 2    October-2024            14    ₹ 341.05  ₹ 596.97        -₹ 255.92
# 3  September-2024             2   -₹ 469.45  ₹ 110.01        -₹ 579.46
# 4     August-2024            11   -₹ 151.10  ₹ 237.74        -₹ 388.84
