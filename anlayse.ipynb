# %%
#importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading data
data = pd.read_csv('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Trade Analyse/PL.csv')
data.head(3)
# Out:
#   Pre Funds       DATE        STOCK    OPTED             VOLUME  RSI   RR  \
# 0       4000  August 5  TATA Motors      BUY      1.4M u - 450k   30    2
# 1       4190  August 7  TATA Motors  No Data  NO DATA AVAILABLE  NaN  NaN
# 2       4042  August 8  TATA Motors      NaN                NaN  NaN  NaN
#
#    TAR RR  PR0 / LOSS Brokerage     NET  Post Funds
# 0     2.0       210.0     20.89  190.69       4190.0
# 1     NaN       126.0      22.1 -148.00       4042.0
# 2     NaN       169.0     21.61 -190.71       3851.0

# %%
#trung to find the columns
columns = data.columns.tolist()
columns
# Out:
# ['Pre Funds ',
#  'DATE',
#  'STOCK',
#  'OPTED',
#  'VOLUME',
#  'RSI',
#  'RR',
#  'TAR RR',
#  'PR0 / LOSS',
#  'Brokerage',
#  'NET',
#  'Post Funds ']

# %%
#to know the no of rows and columns

x = data.size # to know the Rows and columns, no of elements 
rows= data.shape[0] #to know the no of rows and columns
columns = data.shape[1]
print(
    f"{rows} x {columns}\n" # \n is for new line(backlash)
    f"\nNO of elements is {x}"   # File pointer : f"{}"" is the syntax 
    )
# Out:
# 52 x 12
#
# NO of elements is 624

# %%
#defining the function to fill the empty cells
def fill_empty_cells(data, column_name, value):
    data[column_name] = data[column_name].fillna(value,inplace=True)  # Fill NaN with the value for the specific column
    return data

# %%
data.tail(6)
# Out:
#         Pre Funds           DATE        STOCK     OPTED            VOLUME  \
# 46          MONTH   NO OF TRADES  REALIZED PL   CHARGES  NET REALIZED\nPL
# 47    January-2025             8    -₹ 126.37  ₹ 239.70         -₹ 366.07
# 48   November-2024             5    -₹ 947.90  ₹ 119.17       -₹ 1,067.07
# 49    October-2024            14     ₹ 341.05  ₹ 596.97         -₹ 255.92
# 50  September-2024             2    -₹ 469.45  ₹ 110.01         -₹ 579.46
# 51     August-2024            11    -₹ 151.10  ₹ 237.74         -₹ 388.84
#
#     RSI   RR  TAR RR  PR0 / LOSS Brokerage  NET  Post Funds
# 46  NaN  NaN     NaN         NaN       NaN  NaN          NaN
# 47  NaN  NaN     NaN         NaN       NaN  NaN          NaN
# 48  NaN  NaN     NaN         NaN       NaN  NaN          NaN
# 49  NaN  NaN     NaN         NaN       NaN  NaN          NaN
# 50  NaN  NaN     NaN         NaN       NaN  NaN          NaN
# 51  NaN  NaN     NaN         NaN       NaN  NaN          NaN

# %%
data.iloc[:-6].to_csv('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Trade Analyse/PL.csv', index=False)
data.tail(6).to_csv('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Trade Analyse/PL.csv', index=False)

# %%
def fill_empty_cells(data, column_name, value):
    data[column_name].fillna(value, inplace=True)  # Fill NaN values in the column with the specified value
    return data

data = fill_empty_cells(data, 'Brokerage', 30)  # This will fill NaN values in 'Brokerage' with 30

# %%
data['Brokerage'] = fill_empty_cells(data, 'Brokerage',30)

# %%
data1 = pd.read_csv('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Trade Analyse/data.csv')
data1 = data1.iloc[:-7]
data1.tail(5)
# Out:
#     Pre Funds     DATE     STOCK OPTED       VOLUME  RSI   RR  TAR RR  \
# 34     7979.90   9 Jan       M&M  Sell      60k-24k   73    L     1.9
# 35     7843.11  10 Jan     IREDA   Buy      4M-1.7M   28    L     2.0
# 36     7632.60  13 Jan       TCS  Sell           NO  NaN    L     2.0
# 37     7492.04  14 Jan  Reliance   BUY          NaN  NaN    L     2.0
# 38     7427.48  20 Jan        LT  Sell  39K ↑ - 26k   77  Lx2     3.0
#
#     PR0 / LOSS  Brokerage     NET  Post Funds
# 34     -106.75        NaN -136.79      7843.11
# 35     -197.47        NaN -210.51      7632.60
# 36     -167.70        NaN -140.56      7492.04
# 37      -91.00        NaN  -64.56      7427.48
# 38      -53.00        NaN -129.20      7298.28

# %%
data1.head(40)
# Out:
#     Pre Funds          DATE            STOCK    OPTED  \
# 0      4000.00     August 5      TATA Motors      BUY
# 1      4190.00     August 7      TATA Motors  No Data
# 2      4042.00     August 8      TATA Motors      NaN
# 3      3851.00    August 12      TATA Motors      NaN
# 4      3742.21    August 13      TATA Motors      NaN
# 5      3819.65    August 14      TATA Motors      NaN
# 6          NaN    August 16      TATA Motors      NaN
# 7          NaN    August 19      TATA Motors      NaN
# 8      3708.00    August 20      TATA Motors      NaN
# 9      3690.00    August 21      TATA Motors      NaN
# 10     3690.00    August 22      TATA Motors      NaN
# 11     8587.61       11 Sep          Oracle      Buy
# 12     8287.00       11 Sep          Oracle      sell
# 13     8123.00       12 Sep          Oracle      Sell
# 14    18284.00   October 10              TCS     SELL
# 15         NaN          NaN              NaN      NaN
# ...

# %%
def nan_filler(data1,fill_value):
    for column, value in fill_value.items():
        data1[column]= data1[column].fillna(value)
    return data1

# %%
data1.head(1)
# Out:
#    Pre Funds       DATE        STOCK OPTED         VOLUME RSI RR  TAR RR  \
# 0      4000.0  August 5  TATA Motors   BUY  1.4M u - 450k  30  2     2.0
#
#    PR0 / LOSS  Brokerage     NET  Post Funds
# 0       210.0        NaN  190.69       4190.0

# %%
def fill_date( data1, column_name):
    data1[column_name]= data1[column_name].fillna(method='ffill')
    return data1

data1 = fill_date(data1, 'DATE')
data1.head(39)
# Out:
# /var/folders/10/4p6gdwfx3g74kjfj2_xqxz140000gn/T/ipykernel_39513/369396471.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1[column_name]= data1[column_name].fillna(method='ffill')
#     Pre Funds          DATE            STOCK    OPTED  \
# 0      4000.00     August 5      TATA Motors      BUY
# 1      4190.00     August 7      TATA Motors  No Data
# 2      4042.00     August 8      TATA Motors      NaN
# 3      3851.00    August 12      TATA Motors      NaN
# 4      3742.21    August 13      TATA Motors      NaN
# 5      3819.65    August 14      TATA Motors      NaN
# 6          NaN    August 16      TATA Motors      NaN
# 7          NaN    August 19      TATA Motors      NaN
# 8      3708.00    August 20      TATA Motors      NaN
# 9      3690.00    August 21      TATA Motors      NaN
# 10     3690.00    August 22      TATA Motors      NaN
# ...

# %%
brok = pd.read_csv('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Trade Analyse/last_6.csv')
brok.head(6)
# Out:
#        Pre Funds           DATE        STOCK     OPTED            VOLUME  RSI  \
# 0          MONTH   NO OF TRADES  REALIZED PL   CHARGES  NET REALIZED\nPL  NaN
# 1    January-2025             8    -₹ 126.37  ₹ 239.70         -₹ 366.07  NaN
# 2   November-2024             5    -₹ 947.90  ₹ 119.17       -₹ 1,067.07  NaN
# 3    October-2024            14     ₹ 341.05  ₹ 596.97         -₹ 255.92  NaN
# 4  September-2024             2    -₹ 469.45  ₹ 110.01         -₹ 579.46  NaN
# 5     August-2024            11    -₹ 151.10  ₹ 237.74         -₹ 388.84  NaN
#
#    RR  TAR RR  PR0 / LOSS  Brokerage  NET  Post Funds
# 0 NaN     NaN         NaN        NaN  NaN          NaN
# 1 NaN     NaN         NaN        NaN  NaN          NaN
# 2 NaN     NaN         NaN        NaN  NaN          NaN
# 3 NaN     NaN         NaN        NaN  NaN          NaN
# 4 NaN     NaN         NaN        NaN  NaN          NaN
# 5 NaN     NaN         NaN        NaN  NaN          NaN

# %%
brok.columns = brok.iloc[0]
brok = brok.drop(0)
brok = brok.reset_index(drop=True)
brok = brok.iloc[:,:-7]

brok.head(6)
brokerage = brok.to_csv('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Cleaned_Data/Brokerage.csv',index=False)

# %%
brok.dtypes
# Out:
# 0
# MONTH                object
# NO OF TRADES          int64
# REALIZED PL           int64
# CHARGES               int64
# NET REALIZED\nPL      int64
# AVGPL/TRADE         float64
# BROK/TRADE          float64
# dtype: object

# %%
# Remove ₹, commas, and non-breaking spaces (\xa0), and then convert to float and int
brok['CHARGES'] = brok['CHARGES'].replace({'₹': '', ',': ''}, regex=True).astype(float).astype(int)
brok['REALIZED PL'] = brok['REALIZED PL'].replace({'₹': '', ',': '', '\xa0': ''}, regex=True).astype(float).astype(int)
brok['NET REALIZED\nPL'] = brok['NET REALIZED\nPL'].replace({'₹': '', ',': '', '\xa0': ''}, regex=True).astype(float).astype(int)
brok['NO OF TRADES'] = brok['NO OF TRADES'].astype(int)
brok['AVGPL/TRADE']=brok['AVGPL/TRADE'].astype(int)
brok['BROK/TRADE']=brok['BROK/TRADE'].astype(int)
brok['AVGPL/TRADE']=brok['NET REALIZED\nPL']/brok['NO OF TRADES']
brok['BROK/TRADE']=brok['CHARGES']/brok['NO OF TRADES']

brok.dtypes
# Out:
# 0
# MONTH                object
# NO OF TRADES          int64
# REALIZED PL           int64
# CHARGES               int64
# NET REALIZED\nPL      int64
# AVGPL/TRADE         float64
# BROK/TRADE          float64
# dtype: object

# %%
brok.head(6)
# Out:
# 0          MONTH   NO OF TRADES  REALIZED PL  CHARGES  NET REALIZED\nPL  \
# 0    January-2025             8         -126      239              -366
# 1   November-2024             5         -947      119             -1067
# 2    October-2024            14          341      596              -255
# 3  September-2024             2         -469      110              -579
# 4     August-2024            11         -151      237              -388
#
# 0  AVGPL/TRADE  BROK/TRADE
# 0   -45.750000   29.875000
# 1  -213.400000   23.800000
# 2   -18.214286   42.571429
# 3  -289.500000   55.000000
# 4   -35.272727   21.545455

# %%
data1.head(6)
# Out:
#    Pre Funds        DATE        STOCK    OPTED             VOLUME  RSI   RR  \
# 0     4000.00   August 5  TATA Motors      BUY      1.4M u - 450k   30    2
# 1     4190.00   August 7  TATA Motors  No Data  NO DATA AVAILABLE  NaN  NaN
# 2     4042.00   August 8  TATA Motors      NaN                NaN  NaN  NaN
# 3     3851.00  August 12  TATA Motors      NaN                NaN  NaN  NaN
# 4     3742.21  August 13  TATA Motors      NaN                NaN  NaN  NaN
# 5     3819.65  August 14  TATA Motors      NaN                NaN  NaN  NaN
#
#    TAR RR  PR0 / LOSS  Brokerage     NET  Post Funds
# 0     2.0      210.00        NaN  190.69      4190.00
# 1     NaN      126.00        NaN -148.00      4042.00
# 2     NaN      169.00        NaN -190.71      3851.00
# 3     NaN       88.00        NaN -108.79      3742.21
# 4     NaN      115.94        NaN   77.44      3819.65
# 5     NaN      141.15        NaN  122.06      3919.50
