# %%
import pandas as pd

# %%
data2 = pd.read_csv('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Trade Analyse/data_by_angelone.csv')
data2.head(20)
# Out:
#                     Date Range  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                    From Date  31/07/2024        NaN        NaN        NaN
# 1                      To Date  20/01/2025        NaN        NaN        NaN
# 2                          NaN         NaN        NaN        NaN        NaN
# 3           Equity P&L Summary         NaN        NaN        NaN        NaN
# 4              Total Gross PnL    -1353.77        NaN        NaN        NaN
# 5              Total Brokerage      733.99        NaN        NaN        NaN
# 6                    Total GST      146.35        NaN        NaN        NaN
# 7   Total Exchange Service Tax           0        NaN        NaN        NaN
# 8           Total Turnover Tax       75.06        NaN        NaN        NaN
# 9           Total SEBI Charges        2.47        NaN        NaN        NaN
# 10            Total Stamp Duty          41        NaN        NaN        NaN
# ...

# %%
 #first 18 rows of the data are seperated and made a new data frame
data2.iloc[:18].to_csv('/Users/surisettivamsikrishna/Downloads/Vamsi Pc/CODES/Mark 3/Trade Analyse/Angelone_part1.csv')
