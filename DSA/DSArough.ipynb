# %%
a = 121
count = 0

c=[]
while a>0:
    a=a//10
    c.append(a)
    count+=1

print(count)
# Out:
# 3

# %%
a=["house","home","horse"]
b= ["parrot","dag","leb"]


lisn = [list(i) for i in b]



for index, word in enumerate(lisn):
  globals()[f"var{index}"]= word

print(var0)
print(var1)
print(var2)
# Out:
# ['p', 'a', 'r', 'r', 'o', 't']
# ['d', 'a', 'g']
# ['l', 'e', 'b']

# %%
p= list(set(var0)&set(var1)&set(var2))
print(p)
# Out:
# []
